# %%
# !pip install -q git+https://colab:BzYaFze7Rc15wg6ZZEya@gitlab.com/steplerchik/motion-planner.git@develop

# %%
import numpy as np
from motion_planner import *

# %%
end_position = np.array([5.0, 8.0, 0])
nf = NavigationFunctionNF1(end_position, resolution=0.5)
nf.get_cost_map()
cost = nf.get_cost(np.array([5, 5, 0]))
plot_cost_map(nf)
print("Cost:", cost)
# Out:
# 0.09553273216077784
# 0.13237874351408596
# 0.09553273216077784
# 0.13237874351408596
# 0.09553273216077784
# 0.13237874351408596
# 0.09553273216077784
# 0.13237874351408596
# 0.21526497262695232
# 0.1819389614074528
# 0.21526497262695232
# 0.21526497262695232
# 0.1819389614074528
# 0.21526497262695232
# 0.21526497262695232
# 0.1819389614074528
# 0.21526497262695232
# 0.1819389614074528
# 0.21526497262695232
# 0.21526497262695232
# 0.24723335529380375
# 0.24723335529380375
# 0.24723335529380375
# 0.24723335529380375
# 0.2902328538141624
# 0.26009056749848236
# 0.2902328538141624
# 0.2902328538141624
# 0.26009056749848236
# 0.2902328538141624
# 0.26009056749848236
# 0.2902328538141624
# 0.2902328538141624
# 0.3191472095420882
# 0.3191472095420882
# 0.3191472095420882
# 0.3191472095420882
# 0.3191472095420882
# 0.3191472095420882
# 0.3468836578793244
# 0.3468836578793244
# 0.35803884848725365
# 0.3307761371368829
# 0.35803884848725365
# 0.35803884848725365
# 0.3307761371368829
# ...
